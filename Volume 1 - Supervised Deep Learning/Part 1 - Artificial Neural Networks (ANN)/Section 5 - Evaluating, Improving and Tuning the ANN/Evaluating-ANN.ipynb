# %% [markdown]
# ## Evaluating our ANN model

# %% [markdown]
# ### Index
# - [Equation and Method](#equation)
# - [Pre processing](#preprocessing)
# - [Building the model](#building)

# %%
# importing some basic libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
# Out:
# Using TensorFlow backend.

# %% [markdown]
# <a id='equation'></a>
# ##### Equation and Method
#
# The Evaluation of ANN is similar to scikit learn models, We use a scikit learn keras wrapper to apply the same grid search and K-fold cross validation.

# %% [markdown]
# <a id='preprocessing'></a>
# ##### Pre processing

# %%
dataset = pd.read_csv('Churn_Modelling.csv')
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
## Changing into dummy variables.
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])
onehotencoder = OneHotEncoder(categorical_features = [1])
X = onehotencoder.fit_transform(X).toarray()
X = X[:, 1:]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# <a id='building'></a>
# ##### Building the model

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from keras.models import Sequential
from keras.layers import Dense

# %%
def build_classifier_1():
    
    classifier = Sequential()
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    
    return classifier

# %% [markdown]
# #### K Fold cross validation

# %%
classifier = KerasClassifier(build_fn = build_classifier_1, batch_size = 10, epochs = 100)
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10, n_jobs = -1)
mean = accuracies.mean()
variance = accuracies.std()
# Out:
# Epoch 1/100
# Epoch 1/100
# Epoch 1/100
# Epoch 1/100
# ...
# 7200/7200 [==============================] - 1s 162us/step - loss: 0.4910 - acc: 0.7951
# Epoch 2/100
# Epoch 2/100
# 7200/7200 [==============================] - 1s 171us/step - loss: 0.4895 - acc: 0.7964
# Epoch 2/100
# 7200/7200 [==============================] - 1s 177us/step - loss: 0.4900 - acc: 0.7971
# Epoch 2/100
# 7200/7200 [==============================] - 1s 118us/step - loss: 0.4309 - acc: 0.7956
# Epoch 3/100
# 7200/7200 [==============================] - 1s 121us/step - loss: 0.4164 - acc: 0.8201
# Epoch 3/100
# 7200/7200 [==============================] - 1s 124us/step - loss: 0.4273 - acc: 0.7975
# Epoch 3/100
# 7200/7200 [==============================] - 1s 155us/step - loss: 0.4290 - acc: 0.7967
# Epoch 3/100
# 7200/7200 [==============================] - 1s 121us/step - loss: 0.4024 - acc: 0.8275
# Epoch 4/100
# 7200/7200 [==============================] - 1s 132us/step - loss: 0.4259 - acc: 0.7956
# ...

# %%
mean, variance
# Out:
# (0.8343749954178928, 0.01094374720558353)

# %% [markdown]
# We can evaluate the model similar to machine learning models using this wrapper.

# %% [markdown]
# #### Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %%
def build_classifier(optimizer):
    classifier = Sequential()
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = optimizer, loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier

# %%
classifier = KerasClassifier(build_fn = build_classifier)

# %%
parameters = {
                'batch_size': [25, 32],
                'epochs': [100, 500],
                'optimizer': ['adam', 'rmsprop']
            }

# %%
grid_search = GridSearchCV(estimator = classifier,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10)

# %%
result = grid_search.fit(X_train, y_train)
# Out:
# Epoch 1/100
# 7200/7200 [==============================] - 0s 46us/step - loss: 0.5574 - acc: 0.7965
# Epoch 2/100
# 7200/7200 [==============================] - 0s 27us/step - loss: 0.4347 - acc: 0.7971
# Epoch 3/100
# 7200/7200 [==============================] - 0s 27us/step - loss: 0.4277 - acc: 0.7971
# Epoch 4/100
# 7200/7200 [==============================] - 0s 29us/step - loss: 0.4238 - acc: 0.7971
# Epoch 5/100
# 7200/7200 [==============================] - 0s 27us/step - loss: 0.4196 - acc: 0.8122
# Epoch 6/100
# 7200/7200 [==============================] - 0s 28us/step - loss: 0.4160 - acc: 0.8265
# Epoch 7/100
# 7200/7200 [==============================] - 0s 27us/step - loss: 0.4131 - acc: 0.8286
# Epoch 8/100
# 7200/7200 [==============================] - 0s 26us/step - loss: 0.4100 - acc: 0.8293
# Epoch 9/100
# 7200/7200 [==============================] - 0s 27us/step - loss: 0.4078 - acc: 0.8310
# Epoch 10/100
# ...

# %%
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-3983f33ced75> in <module>()
# ----> 1 best_parameters = grid_search.best_params_
#       2 best_accuracy = grid_search.best_score_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %%
best_parameters, best_accuracy
